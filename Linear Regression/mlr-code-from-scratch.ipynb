# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/datasets/faizanhaider01/multiple-linear-regression/student_scores.csv

# %%
df = pd.read_csv('/kaggle/input/datasets/faizanhaider01/multiple-linear-regression/student_scores.csv')

# %%
df.sample(5)
# Out:
#     study_hours  attendance_pct  exam_score
# 92          7.8            95.0        75.4
# 51          8.0            62.0        81.9
# 25          8.1            71.4        87.9
# 93          6.1            81.7        69.4
# 37          1.9            85.2        43.4

# %%
 X = df.drop('exam_score', axis=1)

# %%
X.shape
# Out:
# (100, 2)

# %%
y = df['exam_score']

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (80, 2)
# (20, 2)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6656560242181646

# %%
reg.coef_
# Out:
# array([4.29554729, 0.41215101])

# %%
reg.intercept_
# Out:
# np.float64(13.408233400870685)

# %% [markdown]
# # Making our own Linear Regression Class

# %%
class MLR_Scratch:
    def __init__(self):
        self.intercept = None
        self.coeff = None
    def fit(self,X_train,y_train):
        X_train = np.insert(X_train,0,1,axis = 1)
        betas = np.linalg.inv(np.dot(X_train.T,X_train)).dot(X_train.T).dot(y_train)
        self.intercept = betas[0]
        self.coeff = betas[1:]
    def prediction(self,X_test):
        y_pred = np.dot(X_test,self.coeff)+ self.intercept
        return y_pred

# %%
mlr = MLR_Scratch()

# %%
mlr.fit(X_train,y_train)

# %%
mlr.coeff
# Out:
# array([4.29554729, 0.41215101])

# %%
mlr.intercept
# Out:
# np.float64(13.408233400870529)

# %%
y.pred = mlr.prediction(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6656560242181646
