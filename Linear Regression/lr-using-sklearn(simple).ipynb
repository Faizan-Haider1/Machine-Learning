# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/datasets/faizanhaider01/student-grade/linear_regression_data.csv

# %%
df = pd.read_csv('/kaggle/input/datasets/faizanhaider01/student-grade/linear_regression_data.csv')

# %%
df.head()
# Out:
#    study_hours  exam_score
# 0          1.2        52.3
# 1          2.5        61.8
# 2          0.8        48.7
# 3          3.1        68.4
# 4          4.0        75.2

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['study_hours'],df['exam_score'])
plt.xlabel('study_hours')
plt.ylabel('exam_score')
# Out:
# Text(0, 0.5, 'exam_score')

# %%
X = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict(X_test.iloc[0].values.reshape(1,1))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([82.2442934])

# %%
plt.scatter(df['study_hours'],df['exam_score'])
plt.plot(X_train,lr.predict(X_train),color='yellow')
plt.xlabel('study_hours')
plt.ylabel('exam_score')
# Out:
# Text(0, 0.5, 'exam_score')

# %%
m = lr.coef_

# %%
m
# Out:
# array([7.96020737])

# %%
b = lr.intercept_

# %%
b
# Out:
# np.float64(43.23927730283418)

# %%
X_test
# Out:
#      study_hours
# 131          4.9
# 139          4.3
# 10           0.5
# 65           0.8
# 157          3.3
# 94           4.0
# 175          1.9
# 183          4.2
# 142          3.4
# 13           1.0
# 25           1.3
# 122          1.2
# 135          3.7
# 151          2.1
# 54           6.3
# 23           2.7
# 109          4.4
# 41           4.8
# 44           5.2
# 189          6.4
# 24           6.8
# 71           4.9
# 190          1.5
# 115          1.9
# 198          1.8
# 144          6.8
# 66           5.1
# 147          2.4
# 89           5.5
# 6            5.3
# 28           0.9
# 12           2.9
# 29           5.5
# 18           1.8
# 35           0.7
# 5            2.2
# 108          1.7
# 2            0.8
# 130          1.5
# 3            3.1
# 158          2.8
# 14           5.8
# 140          0.5

# %%
m * 4.9 + b   # lr.predict matched
# Out:
# array([82.2442934])
